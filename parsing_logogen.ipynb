# %%
import numpy as np
import pandas as pd
pd.set_option("precision", 3)
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/locogen.csv')

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df
# Out:
#                     time  Asset Man  Board  Break  Cons  Energy  Lobby  \
# 0    2021-01-01 00:30:00       18.2   20.2   14.1  18.5    19.2   18.1
# 1    2021-01-01 01:00:00       18.2   21.4   14.2  18.6    18.4   18.1
# 2    2021-01-01 01:30:00       18.4   20.7   14.2  18.8    17.4   18.1
# 3    2021-01-01 02:00:00       18.2   20.0   14.2  18.7    16.8   18.1
# 4    2021-01-01 02:30:00       18.3   19.3   14.2  18.7    16.4   18.0
# ...                  ...        ...    ...    ...   ...     ...    ...
# 5688 2021-04-29 21:30:00       20.5   19.6   18.1  21.6    17.7   18.0
# 5689 2021-04-29 22:00:00       20.3   19.5   18.0  21.4    17.5   17.7
# 5690 2021-04-29 22:30:00       20.2   19.4   18.0  21.2    17.5   17.6
# 5691 2021-04-29 23:00:00       20.2   19.2   18.1  21.3    17.7   18.5
# 5692 2021-04-29 23:30:00       20.3   19.2   17.9  21.7    17.9   19.1
#
#       Management  Meeting  Other (Kitchen)  Sales  weather_temperature
# ...

# %%
df.describe()
# Out:
#        Asset Man     Board     Break      Cons    Energy     Lobby  \
# count   5649.000  5647.000  5655.000  5636.000  5654.000  5646.000
# mean      14.459    12.771    11.966    14.986    12.791    12.792
# std        5.536     5.549     5.270     5.704     5.353     5.150
# min        5.700     4.000     4.400     5.800     5.300     5.700
# 25%        8.500     6.700     6.200     8.800     7.500     7.600
# 50%       15.800    13.700    11.800    16.650    12.100    12.300
# 75%       19.300    17.500    17.500    20.100    17.500    18.000
# max       24.300    24.800    19.100    23.900    22.700    20.700
#
#        Management   Meeting  Other (Kitchen)     Sales  weather_temperature
# count    5661.000  5643.000         5619.000  5648.000             5693.000
# mean       12.948    10.765           12.179    13.258                4.950
# std         5.125     5.030            5.946     5.390                3.878
# ...

# %%
fig, ax = plt.subplots(3,4, figsize=(15,10))
df.hist(ax=ax.ravel()[:-1]);
